# %% [markdown]
# # Classification Problem

# %%
import pandas as pd
from autosklearn.classification import AutoSklearnClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# 載入資料
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# 初始化 & 訓練 AutoSklearn
automl = AutoSklearnClassifier(time_left_for_this_task=300, per_run_time_limit=60, n_jobs=-1)
automl.fit(X_train, y_train)

# 評估
y_pred = automl.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# ✅ 取得模型資訊
models_with_weights = automl.get_models_with_weights()
model_infos = []

for weight, model in models_with_weights:
    try:
        clf = model.steps[-1][1].choice 
        params = clf.get_params()
    except Exception:
        clf = model.steps[-1][1]  
        params = "無法讀取參數"

    model_infos.append({
        "模型": clf.__class__.__name__,
        "集成權重": weight,
        "參數": params
    })

df_models = pd.DataFrame(model_infos)
pd.set_option("display.max_colwidth", None)
display(df_models)
# Out:
# Accuracy: 0.986013986013986
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        54
#            1       0.99      0.99      0.99        89
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.99      0.99       143
# weighted avg       0.99      0.99      0.99       143
#                             模型  集成權重  \
# 0                MLPClassifier  0.08
# 1                MLPClassifier  0.08
# 2   GradientBoostingClassifier  0.06
# 3                MLPClassifier  0.06
# 4                MLPClassifier  0.06
# 5                MLPClassifier  0.04
# 6                MLPClassifier  0.04
# 7                MLPClassifier  0.04
# 8                MLPClassifier  0.04
# 9                MLPClassifier  0.04
# 10               MLPClassifier  0.04
# 11               MLPClassifier  0.02
# 12               MLPClassifier  0.02
# 13        ExtraTreesClassifier  0.02
# 14  GradientBoostingClassifier  0.02
# 15  GradientBoostingClassifier  0.02
# 16          AdaboostClassifier  0.02
# 17               MLPClassifier  0.02
# 18               MLPClassifier  0.02
# 19               MLPClassifier  0.02
# 20               MLPClassifier  0.02
# 21               MLPClassifier  0.02
# 22  GradientBoostingClassifier  0.02
# 23               MLPClassifier  0.02
# 24               MLPClassifier  0.02
# 25               MLPClassifier  0.02
# 26               MLPClassifier  0.02
# 27               MLPClassifier  0.02
# 28               MLPClassifier  0.02
# 29               MLPClassifier  0.02
# 30               MLPClassifier  0.02
# 31               MLPClassifier  0.02
#
#                                                                                                                                                                                                                                                                                                                                                                                                       參數
# 0     {'activation': 'relu', 'alpha': 0.0002851216704591682, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0001425610939940889, 'n_iter_no_change': 32, 'num_nodes_per_layer': 121, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 1    {'activation': 'relu', 'alpha': 5.456608909743626e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00028353610920763976, 'n_iter_no_change': 32, 'num_nodes_per_layer': 153, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 2                                                                        {'early_stop': 'train', 'l2_regularization': 0.005326508887463406, 'learning_rate': 0.060800813211425456, 'loss': 'auto', 'max_bins': 255, 'max_depth': None, 'max_leaf_nodes': 6, 'min_samples_leaf': 5, 'n_iter_no_change': 5, 'random_state': 1, 'scoring': 'loss', 'tol': 1e-07, 'validation_fraction': None, 'verbose': 0}
# 3    {'activation': 'relu', 'alpha': 0.0001349523460162756, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00019316400738792107, 'n_iter_no_change': 32, 'num_nodes_per_layer': 111, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 4     {'activation': 'tanh', 'alpha': 5.650839254360318e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0003554589568433362, 'n_iter_no_change': 32, 'num_nodes_per_layer': 232, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 5      {'activation': 'relu', 'alpha': 0.00013634467833691693, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 2, 'learning_rate_init': 0.001212394084719187, 'n_iter_no_change': 32, 'num_nodes_per_layer': 27, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 6     {'activation': 'relu', 'alpha': 8.984344207799962e-06, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 1, 'learning_rate_init': 0.0003404659443259394, 'n_iter_no_change': 32, 'num_nodes_per_layer': 141, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 7     {'activation': 'relu', 'alpha': 1.880504115410201e-06, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0003404659443259394, 'n_iter_no_change': 32, 'num_nodes_per_layer': 121, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 8      {'activation': 'relu', 'alpha': 0.0001344291873668423, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.000622150550797747, 'n_iter_no_change': 32, 'num_nodes_per_layer': 115, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 9         {'activation': 'relu', 'alpha': 6.92471594660872e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 1, 'learning_rate_init': 0.3916859656158691, 'n_iter_no_change': 32, 'num_nodes_per_layer': 191, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 10    {'activation': 'tanh', 'alpha': 0.000852195460251887, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00015895054618035508, 'n_iter_no_change': 32, 'num_nodes_per_layer': 104, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 11   {'activation': 'tanh', 'alpha': 0.0001363185819149026, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00018009776276177523, 'n_iter_no_change': 32, 'num_nodes_per_layer': 115, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 12    {'activation': 'relu', 'alpha': 0.0017940473175767063, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 2, 'learning_rate_init': 0.0004684917334431039, 'n_iter_no_change': 32, 'num_nodes_per_layer': 101, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 13                                                                       {'bootstrap': False, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 0.9292309396985746, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'n_jobs': 1, 'oob_score': False, 'random_state': 1, 'verbose': 0}
# 14                                                                      {'early_stop': 'off', 'l2_regularization': 1.0647401999412075e-10, 'learning_rate': 0.08291320147381159, 'loss': 'auto', 'max_bins': 255, 'max_depth': None, 'max_leaf_nodes': 39, 'min_samples_leaf': 20, 'n_iter_no_change': 0, 'random_state': 1, 'scoring': 'loss', 'tol': 1e-07, 'validation_fraction': None, 'verbose': 0}
# 15                                                                    {'early_stop': 'train', 'l2_regularization': 3.387912939529945e-10, 'learning_rate': 0.30755227194768237, 'loss': 'auto', 'max_bins': 255, 'max_depth': None, 'max_leaf_nodes': 60, 'min_samples_leaf': 39, 'n_iter_no_change': 18, 'random_state': 1, 'scoring': 'loss', 'tol': 1e-07, 'validation_fraction': None, 'verbose': 0}
# 16                                                                                                                                                                                                                                                                                {'algorithm': 'SAMME.R', 'learning_rate': 0.02212453622490893, 'max_depth': 2, 'n_estimators': 421, 'random_state': 1}
# 17   {'activation': 'tanh', 'alpha': 0.00021148999718383549, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0002706030575711377, 'n_iter_no_change': 32, 'num_nodes_per_layer': 117, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 18    {'activation': 'relu', 'alpha': 7.043993167459616e-06, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 1, 'learning_rate_init': 0.0005346595397263682, 'n_iter_no_change': 32, 'num_nodes_per_layer': 126, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 19   {'activation': 'relu', 'alpha': 0.00013634467833691693, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00039690882317480834, 'n_iter_no_change': 32, 'num_nodes_per_layer': 27, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 20  {'activation': 'tanh', 'alpha': 0.00016533459423547956, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00022465957483940827, 'n_iter_no_change': 32, 'num_nodes_per_layer': 115, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 21    {'activation': 'relu', 'alpha': 0.0001363185819149026, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 2, 'learning_rate_init': 0.0007789617646230673, 'n_iter_no_change': 32, 'num_nodes_per_layer': 115, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 22                                                                      {'early_stop': 'train', 'l2_regularization': 1.0718652031881264e-07, 'learning_rate': 0.6254220386109288, 'loss': 'auto', 'max_bins': 255, 'max_depth': None, 'max_leaf_nodes': 7, 'min_samples_leaf': 1, 'n_iter_no_change': 18, 'random_state': 1, 'scoring': 'loss', 'tol': 1e-07, 'validation_fraction': None, 'verbose': 0}
# 23    {'activation': 'relu', 'alpha': 3.3882727009715414e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.000632417566310718, 'n_iter_no_change': 32, 'num_nodes_per_layer': 107, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 24    {'activation': 'relu', 'alpha': 7.658644516657131e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0004213575290747623, 'n_iter_no_change': 32, 'num_nodes_per_layer': 173, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 25     {'activation': 'relu', 'alpha': 5.779192494602772e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0003756140188303874, 'n_iter_no_change': 32, 'num_nodes_per_layer': 97, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 26   {'activation': 'relu', 'alpha': 0.00010535227884091285, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 2, 'learning_rate_init': 0.0002940034747756323, 'n_iter_no_change': 32, 'num_nodes_per_layer': 121, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 27     {'activation': 'relu', 'alpha': 6.41530728417527e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0003554589568433362, 'n_iter_no_change': 32, 'num_nodes_per_layer': 195, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 28        {'activation': 'relu', 'alpha': 5.867222842849076e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.2994322635121044, 'n_iter_no_change': 32, 'num_nodes_per_layer': 52, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 29   {'activation': 'relu', 'alpha': 2.270543175220864e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00028353610920763976, 'n_iter_no_change': 32, 'num_nodes_per_layer': 152, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
# 30   {'activation': 'tanh', 'alpha': 5.650839254360318e-07, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'train', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.00016418294906916798, 'n_iter_no_change': 32, 'num_nodes_per_layer': 224, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.0, 'verbose': 0}
# 31      {'activation': 'tanh', 'alpha': 4.0530366568234e-06, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': 'valid', 'epsilon': 1e-08, 'hidden_layer_depth': 3, 'learning_rate_init': 0.0001977651098744155, 'n_iter_no_change': 32, 'num_nodes_per_layer': 108, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0}
