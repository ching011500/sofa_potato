# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %% [markdown]
# Scrape the table

# %%
r = requests.get('https://keithgalli.github.io/web-scraping/webpage.html')
page = bs(r.content, 'html.parser')
table = page.select('table.hockey-stats')[0]
columns = table.find('thead').find_all('th')
columns_names = [c.string for c in columns]
columns_names

rows = table.find('tbody').find_all('tr')
l = []
for row in rows:
    td = row.find_all('td')
    row = [str(i.get_text()) for i in td]
    l.append(row)

df = pd.DataFrame(l, columns=columns_names)
df
# Out:
#                                              S  \
# 0  \n                  2014-15\n
# 1  \n                  2015-16\n
# 2  \n                  2016-17\n
# 3  \n                  2017-18\n
# 4  \n                  2018-19\n
#
#                                                Team        League  GP  G   A  \
# 0            \n\n\n MIT (Mass. Inst. of Tech.) \n\n     ACHA II    17  3   9
# 1            \n\n\n MIT (Mass. Inst. of Tech.) \n\n     ACHA II     9  1   1
# 2            \n\n\n MIT (Mass. Inst. of Tech.) \n\n     ACHA II    12  5   5
# 3  \n                  Did not play\n
# 4            \n\n\n MIT (Mass. Inst. of Tech.) \n\n    ACHA III     8  5  10
#
#    TP PIM +/-        POST  GP   G   A  TP PIM +/-
# 0  12  20       |   \n \n  \n  \n  \n  \n  \n  \n
# 1   2   2       |   \n \n  \n  \n  \n  \n  \n  \n
# 2  10   8   0   |      \n  \n  \n  \n  \n  \n  \n
# 3               |   \n \n  \n  \n  \n  \n  \n  \n
# 4  15   8       |   \n \n  \n  \n  \n  \n  \n  \n
